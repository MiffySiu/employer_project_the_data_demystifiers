# %%
# Import all the necessary packages and libraries
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.stats.api as sms
import sklearn
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns

from sklearn import datasets 
from sklearn import linear_model
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.linear_model import LinearRegression
from statsmodels.formula.api import ols

# %%
# Read the '.csv' file
data = pd.read_csv('Subjects 2017-18.csv') 

# View the head of the df
data.head()
# Out:
#                Subject Area First year marker Level of study Mode of study  \
# 0  (1) Medicine & dentistry               All            All     Full-time
# 1  (1) Medicine & dentistry               All            All     Full-time
# 2  (1) Medicine & dentistry               All            All     Full-time
# 3  (1) Medicine & dentistry               All            All     Full-time
# 4  (1) Medicine & dentistry               All            All     Full-time
#
#   Country of HE provider     Sex Academic Year  Number
# 0                England  Female       2017/18   25825
# 1                England    Male       2017/18   19015
# 2                England   Other       2017/18      45
# 3                England   Total       2017/18   44885
# 4       Northern Ireland  Female       2017/18    1195

# %%
# More info about the DataFrame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25720 entries, 0 to 25719
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Subject Area            25720 non-null  object
#  1   First year marker       25720 non-null  object
#  2   Level of study          25720 non-null  object
#  3   Mode of study           25720 non-null  object
#  4   Country of HE provider  25720 non-null  object
#  5   Sex                     25720 non-null  object
#  6   Academic Year           25720 non-null  object
#  7   Number                  25720 non-null  int64
# dtypes: int64(1), object(7)
# memory usage: 1.6+ MB

# %%
# Prints descriptive statistics
data.describe()
# Out:
#              Number
# count  2.572000e+04
# mean   1.301832e+04
# std    6.861436e+04
# min    0.000000e+00
# 25%    1.500000e+01
# 50%    3.400000e+02
# 75%    3.331250e+03
# max    2.343095e+06

# %%
# Check for missing data
data.isnull().sum()
# Out:
# Subject Area              0
# First year marker         0
# Level of study            0
# Mode of study             0
# Country of HE provider    0
# Sex                       0
# Academic Year             0
# Number                    0
# dtype: int64

# %%
# Check for NaN
datana = data[(data["Number"]=="NaN")]

# %%
# Print df with check for NaN
datana
# Out:
# Empty DataFrame
# Columns: [Subject Area, First year marker, Level of study, Mode of study, Country of HE provider, Sex, Academic Year, Number]
# Index: []

# %%
# Looked at all of data, just data.head(100) left here to decrease file size
data.head(100)
# Out:
#                 Subject Area First year marker Level of study Mode of study  \
# 0   (1) Medicine & dentistry               All            All     Full-time
# 1   (1) Medicine & dentistry               All            All     Full-time
# 2   (1) Medicine & dentistry               All            All     Full-time
# 3   (1) Medicine & dentistry               All            All     Full-time
# 4   (1) Medicine & dentistry               All            All     Full-time
# ..                       ...               ...            ...           ...
# 95  (1) Medicine & dentistry       Other years            All     Part-time
# 96  (1) Medicine & dentistry               All            All           All
# 97  (1) Medicine & dentistry               All            All           All
# 98  (1) Medicine & dentistry               All            All           All
# 99  (1) Medicine & dentistry               All            All           All
#
#    Country of HE provider     Sex Academic Year  Number
# 0                 England  Female       2017/18   25825
# 1                 England    Male       2017/18   19015
# 2                 England   Other       2017/18      45
# 3                 England   Total       2017/18   44885
# 4        Northern Ireland  Female       2017/18    1195
# ..                    ...     ...           ...     ...
# 95                  Wales   Total       2017/18     400
# 96                England  Female       2017/18   30325
# 97                England    Male       2017/18   22500
# 98                England   Other       2017/18      60
# 99                England   Total       2017/18   52885
#
# [100 rows x 8 columns]

# %%
# Check the distribution of the df
# Minimum values of the df
data.min()
# Out:
# Subject Area              (1) Medicine & dentistry
# First year marker                              All
# Level of study                                 All
# Mode of study                                  All
# Country of HE provider                         All
# Sex                                         Female
# Academic Year                              2017/18
# Number                                           0
# dtype: object

# %%
# Maximum values of the df
data.max()
# Out:
# Subject Area              Total - Science subject areas
# First year marker                           Other years
# Level of study                    Postgraduate (taught)
# Mode of study                                 Part-time
# Country of HE provider                            Wales
# Sex                                               Total
# Academic Year                                   2017/18
# Number                                          2343095
# dtype: object

# %%
# Check for number of variables in each column
data.nunique()
# Out:
# Subject Area                21
# First year marker            3
# Level of study               7
# Mode of study                3
# Country of HE provider       5
# Sex                          4
# Academic Year                1
# Number                    5066
# dtype: int64

# %%
# Pandas drop a column with drop function
data1 = data.drop(['Academic Year'], axis=1)

# %%
# Rename columns
data1.columns = ['Area', 'Year', 'Level', 'Mode', 'Country', 'Sex', 'Number']

# %%
# Check df
data1.head()
# Out:
#                        Area Year Level       Mode           Country     Sex  \
# 0  (1) Medicine & dentistry  All   All  Full-time           England  Female
# 1  (1) Medicine & dentistry  All   All  Full-time           England    Male
# 2  (1) Medicine & dentistry  All   All  Full-time           England   Other
# 3  (1) Medicine & dentistry  All   All  Full-time           England   Total
# 4  (1) Medicine & dentistry  All   All  Full-time  Northern Ireland  Female
#
#    Number
# 0   25825
# 1   19015
# 2      45
# 3   44885
# 4    1195

# %%
# Pivot the df
subjects = ['Area', 'Year', 'Level', 'Mode','Country']

new_df = data1.set_index(['Sex'] + subjects).unstack('Sex')
new_df.head(10)
# Out:
#                                                                Number         \
# Sex                                                            Female   Male
# Area                     Year Level Mode      Country
# (1) Medicine & dentistry All  All   All       All               38340  27475
#                                               England           30325  22500
#                                               Northern Ireland   1350    805
#                                               Scotland           4635   3020
#                                               Wales              2030   1145
#                                     Full-time All               32725  23235
#                                               England           25825  19015
#                                               Northern Ireland   1195    685
#                                               Scotland           4100   2630
#                                               Wales              1600    900
#
#
# Sex                                                            Other  Total
# Area                     Year Level Mode      Country
# (1) Medicine & dentistry All  All   All       All                 65  65875
#                                               England             60  52885
#                                               Northern Ireland     0   2160
#                                               Scotland             0   7655
#                                               Wales                0   3180
#                                     Full-time All                 45  56005
#                                               England             45  44885
#                                               Northern Ireland     0   1880
#                                               Scotland             0   6730
#                                               Wales                0   2505

# %%
# Reset index
df1 = new_df.Number.rename_axis([None], axis=1).reset_index()

# %%
# Check new df
df1.head()
# Out:
#                        Area Year Level Mode           Country  Female   Male  \
# 0  (1) Medicine & dentistry  All   All  All               All   38340  27475
# 1  (1) Medicine & dentistry  All   All  All           England   30325  22500
# 2  (1) Medicine & dentistry  All   All  All  Northern Ireland    1350    805
# 3  (1) Medicine & dentistry  All   All  All          Scotland    4635   3020
# 4  (1) Medicine & dentistry  All   All  All             Wales    2030   1145
#
#    Other  Total
# 0     65  65875
# 1     60  52885
# 2      0   2160
# 3      0   7655
# 4      0   3180

# %%
# Create new columns of percentages for number by sex
df1['Female %'] = (df1['Female']/df1['Total']*100).round(2)
df1['Male %'] = (df1['Male']/df1['Total']*100).round(2)
df1['Other %'] = (df1['Other']/df1['Total']*100).round(2)

# %%
# Check new df
df1.head(3)
# Out:
#                        Area Year Level Mode           Country  Female   Male  \
# 0  (1) Medicine & dentistry  All   All  All               All   38340  27475
# 1  (1) Medicine & dentistry  All   All  All           England   30325  22500
# 2  (1) Medicine & dentistry  All   All  All  Northern Ireland    1350    805
#
#    Other  Total  Female %  Male %  Other %
# 0     65  65875     58.20   41.71     0.10
# 1     60  52885     57.34   42.55     0.11
# 2      0   2160     62.50   37.27     0.00

# %%
# Create new df with just first year students
first_year = df1[(df1["Year"]=="First year")&(df1["Level"]=="All")
                     &(df1["Mode"]=="All")&(df1["Country"]=="All")]

# %%
# Check df
first_year
# Out:
#                                          Area        Year Level Mode Country  \
# 104                  (1) Medicine & dentistry  First year   All  All     All
# 413           (2) Subjects allied to medicine  First year   All  All     All
# 728                   (3) Biological sciences  First year   All  All     All
# 998                    (4) Veterinary science  First year   All  All     All
# 1222       (5) Agriculture & related subjects  First year   All  All     All
# 1535                    (6) Physical sciences  First year   All  All     All
# 1850                (7) Mathematical sciences  First year   All  All     All
# 2163                     (8) Computer science  First year   All  All     All
# 2477             (9) Engineering & technology  First year   All  All     All
# 2792                       (B) Social studies  First year   All  All     All
# 3107                                  (C) Law  First year   All  All     All
# 3422    (D) Business & administrative studies  First year   All  All     All
# 3734  (E) Mass communications & documentation  First year   All  All     All
# 4043                            (F) Languages  First year   All  All     All
# 4358   (G) Historical & philosophical studies  First year   All  All     All
# 4673               (H) Creative arts & design  First year   All  All     All
# 4988                            (I) Education  First year   All  All     All
# 5296                             (J) Combined  First year   All  All     All
# 5590                                    Total  First year   All  All     All
# 5905        Total - Non-science subject areas  First year   All  All     All
# 6220            Total - Science subject areas  First year   All  All     All
#
#       Female    Male  Other    Total  Female %  Male %  Other %
# 104    12070    7585     40    19695     61.28   38.51     0.20
# 413   108115   27925    130   136175     79.39   20.51     0.10
# 728    60300   33070    135    93505     64.49   35.37     0.14
# 998     1675     505      0     2180     76.83   23.17     0.00
# 1222    5785    3730      5     9525     60.73   39.16     0.05
# 1535   15405   18920     30    34355     44.84   55.07     0.09
# 1850    6265   10445     15    16725     37.46   62.45     0.09
# 2163    8400   35945     30    44370     18.93   81.01     0.07
# 2477   12720   51655     25    64395     19.75   80.22     0.04
# 2792   64940   36080    125   101145     64.20   35.67     0.12
# 3107   25910   15085     30    41025     63.16   36.77     0.07
# 3422   84350   81530     55   165935     50.83   49.13     0.03
# 3734   13830    9030     35    22895     60.41   39.44     0.15
# 4043   29285   12950    110    42340     69.17   30.59     0.26
# 4358   17250   14050    100    31400     54.94   44.75     0.32
# 4673   46960   25125    115    72200     65.04   34.80     0.16
# 4988   63230   20745     40    84015     75.26   24.69     0.05
# 5296   10845    6785     15    17640     61.48   38.46     0.09
# 5590  596880  425435   1045  1023360     58.33   41.57     0.10
# 5905  356595  221375    630   578600     61.63   38.26     0.11
# 6220  240285  204065    420   444765     54.03   45.88     0.09

# %%
# Filter df again
subset = first_year.iloc[:, [0,9,10,11]]

# %%
# Reorder rows
year1 = subset.sort_values(by='Female %')

# %%
# Check new df
year1
# Out:
#                                          Area  Female %  Male %  Other %
# 2163                     (8) Computer science     18.93   81.01     0.07
# 2477             (9) Engineering & technology     19.75   80.22     0.04
# 1850                (7) Mathematical sciences     37.46   62.45     0.09
# 1535                    (6) Physical sciences     44.84   55.07     0.09
# 3422    (D) Business & administrative studies     50.83   49.13     0.03
# 6220            Total - Science subject areas     54.03   45.88     0.09
# 4358   (G) Historical & philosophical studies     54.94   44.75     0.32
# 5590                                    Total     58.33   41.57     0.10
# 3734  (E) Mass communications & documentation     60.41   39.44     0.15
# 1222       (5) Agriculture & related subjects     60.73   39.16     0.05
# 104                  (1) Medicine & dentistry     61.28   38.51     0.20
# 5296                             (J) Combined     61.48   38.46     0.09
# 5905        Total - Non-science subject areas     61.63   38.26     0.11
# 3107                                  (C) Law     63.16   36.77     0.07
# 2792                       (B) Social studies     64.20   35.67     0.12
# 728                   (3) Biological sciences     64.49   35.37     0.14
# 4673               (H) Creative arts & design     65.04   34.80     0.16
# 4043                            (F) Languages     69.17   30.59     0.26
# 4988                            (I) Education     75.26   24.69     0.05
# 998                    (4) Veterinary science     76.83   23.17     0.00
# 413           (2) Subjects allied to medicine     79.39   20.51     0.10

# %%
# Set colour palette for seaborn
color = ["pink", "blue", "purple"]
sns.set_palette(color)
sns.palplot(sns.color_palette())

# %%
# Plot First Year Percentage by Gender for 2017-2018
year1.plot(kind='bar', x='Area',
                    stacked=True,  
                    figsize=(14, 14))

plt.legend(loc="upper left", ncol=3)
plt.title("First Year Students 2017-2018 by Gender")
plt.xlabel("Proportion")
plt.ylabel("Subject Area")
plt.show()

# %%
# Filter df again
subset2 = first_year.iloc[:, [0,5,6,7]]

# %%
# Reorder rows
year2 = subset2.sort_values(by='Female')

# %%
# Check new df
year2
# Out:
#                                          Area  Female    Male  Other
# 998                    (4) Veterinary science    1675     505      0
# 1222       (5) Agriculture & related subjects    5785    3730      5
# 1850                (7) Mathematical sciences    6265   10445     15
# 2163                     (8) Computer science    8400   35945     30
# 5296                             (J) Combined   10845    6785     15
# 104                  (1) Medicine & dentistry   12070    7585     40
# 2477             (9) Engineering & technology   12720   51655     25
# 3734  (E) Mass communications & documentation   13830    9030     35
# 1535                    (6) Physical sciences   15405   18920     30
# 4358   (G) Historical & philosophical studies   17250   14050    100
# 3107                                  (C) Law   25910   15085     30
# 4043                            (F) Languages   29285   12950    110
# 4673               (H) Creative arts & design   46960   25125    115
# 728                   (3) Biological sciences   60300   33070    135
# 4988                            (I) Education   63230   20745     40
# 2792                       (B) Social studies   64940   36080    125
# 3422    (D) Business & administrative studies   84350   81530     55
# 413           (2) Subjects allied to medicine  108115   27925    130
# 6220            Total - Science subject areas  240285  204065    420
# 5905        Total - Non-science subject areas  356595  221375    630
# 5590                                    Total  596880  425435   1045

# %%
# Plot First Year Number by Gender for 2017-2018
year2.plot(kind='bar', x='Area',
                    stacked=False,  
                    figsize=(14, 14))

plt.legend(loc="upper left", ncol=3)
plt.title("First Year Students 2017-2018 by Gender")
plt.xlabel("Subject Area")
plt.xticks(rotation = 90)
plt.ylabel("Number")
plt.show()

# %%
# Create new df with all student years
all_years = df1[(df1["Year"]=="All")&(df1["Level"]=="All")
                     &(df1["Mode"]=="All")&(df1["Country"]=="All")]

# %%
# Filter df again
subset = all_years.iloc[:, [0,9,10,11]]

# %%
# Reorder rows
allyears = subset.sort_values(by='Female %')

# %%
# Check new df
allyears
# Out:
#                                          Area  Female %  Male %  Other %
# 2058                     (8) Computer science     17.60   82.34     0.06
# 2372             (9) Engineering & technology     18.21   81.75     0.03
# 1745                (7) Mathematical sciences     36.93   62.99     0.08
# 1430                    (6) Physical sciences     42.46   57.47     0.07
# 3317    (D) Business & administrative studies     49.64   50.34     0.02
# 6115            Total - Science subject areas     51.87   48.07     0.06
# 4253   (G) Historical & philosophical studies     54.75   45.07     0.18
# 5485                                    Total     56.92   43.01     0.07
# 0                    (1) Medicine & dentistry     58.20   41.71     0.10
# 3632  (E) Mass communications & documentation     59.11   40.76     0.13
# 5800        Total - Non-science subject areas     61.24   38.68     0.08
# 5198                             (J) Combined     61.69   38.27     0.04
# 2687                       (B) Social studies     63.23   36.69     0.08
# 3002                                  (C) Law     63.42   36.53     0.05
# 1117       (5) Agriculture & related subjects     64.00   35.95     0.05
# 623                   (3) Biological sciences     64.06   35.86     0.08
# 4568               (H) Creative arts & design     64.71   35.13     0.15
# 3938                            (F) Languages     70.86   28.98     0.16
# 4883                            (I) Education     77.34   22.62     0.04
# 938                    (4) Veterinary science     77.74   22.20     0.00
# 308           (2) Subjects allied to medicine     79.05   20.88     0.06

# %%
# Plot First Year Percentage by Gender for 2017-2018
allyears.plot(kind='bar', x='Area',
                    stacked=True,  
                    figsize=(14, 14))

plt.legend(loc="upper left", ncol=3)
plt.title("All Years Students 2017-2018 by Gender")
plt.xlabel("Proportion")
plt.ylabel("Subject Area")
plt.show()

# %%
# Create new df with first year students, undergraduates
undergrad = df1[(df1["Year"]=="First year")&(df1["Level"]=="All undergraduate")
                     &(df1["Mode"]=="All")&(df1["Country"]=="All")]

# %%
# Filter df again
subset = undergrad.iloc[:, [0,9,10,11]]

# %%
# Reorder rows
first_undergrad = subset.sort_values(by='Female %')

# %%
# Check new df
first_undergrad
# Out:
#                                          Area  Female %  Male %  Other %
# 2193                     (8) Computer science     15.37   84.60     0.05
# 2507             (9) Engineering & technology     16.05   83.90     0.05
# 1880                (7) Mathematical sciences     37.61   62.31     0.08
# 1565                    (6) Physical sciences     44.50   55.44     0.04
# 3452    (D) Business & administrative studies     47.69   52.30     0.01
# 6250            Total - Science subject areas     53.06   46.87     0.07
# 3764  (E) Mass communications & documentation     54.98   44.92     0.07
# 4388   (G) Historical & philosophical studies     55.46   44.25     0.29
# 5620                                    Total     57.42   42.51     0.07
# 1252       (5) Agriculture & related subjects     60.62   39.32     0.07
# 134                  (1) Medicine & dentistry     60.64   39.36     0.05
# 5935        Total - Non-science subject areas     61.07   38.86     0.08
# 5325                             (J) Combined     61.33   38.61     0.06
# 758                   (3) Biological sciences     62.80   37.11     0.10
# 2822                       (B) Social studies     64.11   35.84     0.04
# 4703               (H) Creative arts & design     64.70   35.17     0.13
# 3137                                  (C) Law     65.07   34.93     0.02
# 4073                            (F) Languages     68.81   30.99     0.20
# 1016                   (4) Veterinary science     80.88   19.12     0.00
# 443           (2) Subjects allied to medicine     81.29   18.64     0.08
# 5018                            (I) Education     82.10   17.89     0.01

# %%
# Plot First Year Percentage by Gender for 2017-2018
first_undergrad.plot(kind='bar', x='Area',
                    stacked=True,  
                    figsize=(14, 14))

plt.legend(loc="upper left", ncol=3)
plt.title("First Year Undergraduate Students 2017-2018 by Gender")
plt.xlabel("Proportion")
plt.ylabel("Subject Area")
plt.show()

# %%
# Create new df with first year students, postgraduates
postgrad = df1[(df1["Year"]=="First year")&(df1["Level"]=="All postgraduate")
                     &(df1["Mode"]=="All")&(df1["Country"]=="All")]

# %%
# Filter df again
subset = postgrad.iloc[:, [0,9,10,11]]

# %%
# Reorder rows
first_postgrad = subset.sort_values(by='Female %')

# %%
# Check new df
first_postgrad
# Out:
#                                          Area  Female %  Male %  Other %
# 2492             (9) Engineering & technology     26.93   73.04     0.02
# 2178                     (8) Computer science     28.59   71.29     0.13
# 1865                (7) Mathematical sciences     36.96   62.80     0.24
# 1550                    (6) Physical sciences     45.55   54.26     0.19
# 4373   (G) Historical & philosophical studies     53.69   45.93     0.43
# 3437    (D) Business & administrative studies     54.98   44.96     0.06
# 6235            Total - Science subject areas     56.10   43.75     0.15
# 3122                                  (C) Law     59.58   40.25     0.18
# 5605                                    Total     60.02   39.83     0.16
# 1237       (5) Agriculture & related subjects     61.12   38.65     0.22
# 119                  (1) Medicine & dentistry     61.96   37.68     0.36
# 5920        Total - Non-science subject areas     62.58   37.26     0.16
# 5311                             (J) Combined     64.10   35.90     0.00
# 2807                       (B) Social studies     64.38   35.32     0.28
# 4688               (H) Creative arts & design     66.20   33.56     0.24
# 743                   (3) Biological sciences     68.98   30.77     0.25
# 3749  (E) Mass communications & documentation     69.48   30.23     0.29
# 4058                            (F) Languages     70.33   29.26     0.40
# 5003                            (I) Education     70.71   29.23     0.07
# 1007                   (4) Veterinary science     71.20   28.80     0.00
# 428           (2) Subjects allied to medicine     75.39   24.46     0.14

# %%
# Plot First Year Percentage by Gender for 2017-2018
first_postgrad.plot(kind='bar', x='Area',
                    stacked=True,  
                    figsize=(14, 14))

plt.legend(loc="upper left", ncol=3)
plt.title("First Year Postgraduate Students 2017-2018 by Gender")
plt.xlabel("Proportion")
plt.ylabel("Subject Area")
plt.show()

# %%
# Create new df with first year students, undergrad and postgrad, full time
full = df1[(df1["Year"]=="First year")&(df1["Level"]=="All")
                     &(df1["Mode"]=="Full-time")&(df1["Country"]=="All")]

# %%
# Filter df again
subset = full.iloc[:, [0,9,10,11]]

# %%
# Reorder rows
first_full = subset.sort_values(by='Female %')

# %%
# Check new df
first_full
# Out:
#                                          Area  Female %  Male %  Other %
# 2168                     (8) Computer science     18.21   81.72     0.07
# 2482             (9) Engineering & technology     20.74   79.23     0.03
# 1855                (7) Mathematical sciences     37.10   62.77     0.10
# 1540                    (6) Physical sciences     44.86   55.06     0.08
# 5301                             (J) Combined     48.94   51.06     0.00
# 6225            Total - Science subject areas     50.36   49.56     0.07
# 3427    (D) Business & administrative studies     50.98   48.98     0.03
# 4363   (G) Historical & philosophical studies     54.93   44.89     0.18
# 5595                                    Total     56.55   43.37     0.08
# 3739  (E) Mass communications & documentation     60.16   39.68     0.14
# 5910        Total - Non-science subject areas     60.98   38.94     0.09
# 2797                       (B) Social studies     62.31   37.58     0.11
# 109                  (1) Medicine & dentistry     62.35   37.46     0.19
# 733                   (3) Biological sciences     62.69   37.22     0.10
# 3112                                  (C) Law     63.65   36.31     0.04
# 4678               (H) Creative arts & design     64.93   34.92     0.15
# 1227       (5) Agriculture & related subjects     67.07   32.84     0.08
# 4048                            (F) Languages     71.59   28.28     0.13
# 4993                            (I) Education     77.61   22.36     0.04
# 418           (2) Subjects allied to medicine     78.62   21.32     0.06
# 1001                   (4) Veterinary science     79.19   20.81     0.00

# %%
# Plot First Year Percentage of Gender for 2017-2018
first_full.plot(kind='bar', x='Area',
                    stacked=True,  
                    figsize=(14, 14))

plt.legend(loc="upper left", ncol=3)
plt.title("First Year Full-time Students 2017-2018 by Gender")
plt.xlabel("Proportion")
plt.ylabel("Subject Area")
plt.show()

# %%
# Create new df with first year students, undergrad and postgrad, part time
part = df1[(df1["Year"]=="First year")&(df1["Level"]=="All")
                     &(df1["Mode"]=="Part-time")&(df1["Country"]=="All")]

# %%
# Filter df again
subset = part.iloc[:, [0,9,10,11]]

# %%
# Reorder rows
first_part = subset.sort_values(by='Female %')

# %%
# Check new df
first_part
# Out:
#                                          Area  Female %  Male %  Other %
# 2487             (9) Engineering & technology     14.46   85.44     0.10
# 2173                     (8) Computer science     22.83   77.10     0.07
# 1860                (7) Mathematical sciences     40.44   59.83     0.00
# 1545                    (6) Physical sciences     44.53   55.47     0.00
# 1232       (5) Agriculture & related subjects     49.26   50.59     0.00
# 3432    (D) Business & administrative studies     49.93   50.03     0.04
# 4368   (G) Historical & philosophical studies     54.95   44.10     1.04
# 114                  (1) Medicine & dentistry     57.36   42.40     0.24
# 3117                                  (C) Law     60.40   39.44     0.24
# 4053                            (F) Languages     62.49   36.94     0.58
# 5306                             (J) Combined     63.84   36.05     0.10
# 5915        Total - Non-science subject areas     64.10   35.71     0.20
# 5600                                    Total     64.16   35.66     0.18
# 3744  (E) Mass communications & documentation     64.17   35.00     0.42
# 6230            Total - Science subject areas     64.23   35.62     0.15
# 4683               (H) Creative arts & design     66.30   33.53     0.25
# 1004                   (4) Veterinary science     71.74   28.26     0.00
# 4998                            (I) Education     71.80   28.13     0.07
# 738                   (3) Biological sciences     72.80   26.84     0.36
# 2802                       (B) Social studies     72.84   26.97     0.19
# 423           (2) Subjects allied to medicine     80.26   19.60     0.14

# %%
# Plot First Year Percentage of Male, Female, Other for 2017-2018
first_part.plot(kind='bar', x='Area',
                    stacked=True,  
                    figsize=(14, 14))

plt.legend(loc="upper left", ncol=3)
plt.title("First Year Part-time Students 2017-2018 by Gender")
plt.xlabel("Proportion")
plt.ylabel("Subject Area")
plt.show()

# %%
# Create new df with just first year students for England
eng = df1[(df1["Year"]=="First year")&(df1["Level"]=="All")
                     &(df1["Mode"]=="All")&(df1["Country"]=="England")]

# %%
# Filter df again
subset = eng.iloc[:, [0,9,10,11]]

# %%
# Reorder rows
first_eng = subset.sort_values(by='Female %')

# %%
# Check new df
first_eng
# Out:
#                                          Area  Female %  Male %  Other %
# 2164                     (8) Computer science     18.29   81.66     0.06
# 2478             (9) Engineering & technology     19.98   79.99     0.02
# 1851                (7) Mathematical sciences     36.81   63.08     0.11
# 1536                    (6) Physical sciences     44.56   55.37     0.07
# 3423    (D) Business & administrative studies     50.25   49.71     0.03
# 6221            Total - Science subject areas     54.03   45.88     0.09
# 4359   (G) Historical & philosophical studies     54.63   45.19     0.18
# 5591                                    Total     58.21   41.70     0.09
# 3735  (E) Mass communications & documentation     59.94   39.88     0.15
# 105                  (1) Medicine & dentistry     60.74   39.04     0.25
# 1223       (5) Agriculture & related subjects     60.76   39.24     0.07
# 5906        Total - Non-science subject areas     61.38   38.52     0.09
# 5297                             (J) Combined     63.34   36.50     0.11
# 3108                                  (C) Law     63.37   36.56     0.07
# 2793                       (B) Social studies     63.38   36.49     0.13
# 729                   (3) Biological sciences     64.99   34.90     0.11
# 4674               (H) Creative arts & design     65.33   34.54     0.13
# 4044                            (F) Languages     70.19   29.65     0.16
# 4989                            (I) Education     75.96   24.00     0.05
# 999                    (4) Veterinary science     76.11   24.17     0.00
# 414           (2) Subjects allied to medicine     78.88   21.01     0.11

# %%
# Plot First Year Percentage of Male, Female, Other for 2017-2018
first_eng.plot(kind='bar', x='Area',
                    stacked=True,  
                    figsize=(14, 14))

plt.legend(loc="upper left", ncol=3)
plt.title("First Year Students in England, 2017-2018 by Gender")
plt.xlabel("Proportion")
plt.ylabel("Subject Area")
plt.show()

# %%
# Create new df with just first year students for Scotland
scot = df1[(df1["Year"]=="First year")&(df1["Level"]=="All")
                     &(df1["Mode"]=="All")&(df1["Country"]=="Scotland")]

# %%
# Filter df again
subset = scot.iloc[:, [0,9,10,11]]

# %%
# Reorder rows
first_scot = subset.sort_values(by='Female %')

# %%
# Check new df
first_scot
# Out:
#                                          Area  Female %  Male %  Other %
# 2480             (9) Engineering & technology     20.48   79.46     0.13
# 2166                     (8) Computer science     22.73   77.09     0.19
# 1853                (7) Mathematical sciences     42.69   57.31     0.00
# 1538                    (6) Physical sciences     47.92   51.96     0.25
# 6223            Total - Science subject areas     54.91   44.91     0.18
# 3425    (D) Business & administrative studies     55.90   44.07     0.03
# 4361   (G) Historical & philosophical studies     58.12   40.73     1.26
# 1225       (5) Agriculture & related subjects     58.94   40.68     0.00
# 5593                                    Total     59.98   39.79     0.23
# 3110                                  (C) Law     62.32   37.55     0.13
# 107                  (1) Medicine & dentistry     62.91   37.09     0.00
# 5299                             (J) Combined     64.11   35.75     0.00
# 5908        Total - Non-science subject areas     64.28   35.42     0.29
# 4676               (H) Creative arts & design     65.06   34.53     0.41
# 731                   (3) Biological sciences     65.81   33.65     0.54
# 3737  (E) Mass communications & documentation     66.67   32.97     0.36
# 4046                            (F) Languages     68.45   30.63     0.92
# 2795                       (B) Social studies     68.53   31.29     0.18
# 4991                            (I) Education     76.00   23.95     0.06
# 1000                   (4) Veterinary science     81.33   18.67     0.00
# 416           (2) Subjects allied to medicine     83.20   16.80     0.04

# %%
# Plot First Year Percentage of Male, Female, Other for 2017-2018
first_scot.plot(kind='bar', x='Area',
                    stacked=True,  
                    figsize=(14, 14))

plt.legend(loc="upper left", ncol=3)
plt.title("First Year Students in Scotland, 2017-2018 by Gender")
plt.xlabel("Proportion")
plt.ylabel("Subject Area")
plt.show()

# %%
# Create new df with just first year students for Wales
wales = df1[(df1["Year"]=="First year")&(df1["Level"]=="All")
                     &(df1["Mode"]=="All")&(df1["Country"]=="Wales")]

# %%
# Filter df again
subset = wales.iloc[:, [0,9,10,11]]

# %%
# Reorder rows
first_wales = subset.sort_values(by='Female %')

# %%
# Check new df
first_wales
# Out:
#                                          Area  Female %  Male %  Other %
# 2481             (9) Engineering & technology     14.30   85.70     0.00
# 2167                     (8) Computer science     15.89   83.91     0.00
# 1854                (7) Mathematical sciences     35.51   64.49     0.00
# 1539                    (6) Physical sciences     42.69   57.31     0.23
# 3426    (D) Business & administrative studies     50.23   49.71     0.06
# 6224            Total - Science subject areas     51.11   48.81     0.08
# 4362   (G) Historical & philosophical studies     51.39   48.61     0.00
# 5300                             (J) Combined     55.94   44.06     0.00
# 5594                                    Total     56.36   43.56     0.08
# 732                   (3) Biological sciences     57.25   42.68     0.07
# 4677               (H) Creative arts & design     60.08   39.50     0.28
# 3111                                  (C) Law     60.10   39.90     0.00
# 5909        Total - Non-science subject areas     60.32   39.59     0.09
# 3738  (E) Mass communications & documentation     61.04   38.96     0.00
# 4047                            (F) Languages     61.74   38.02     0.12
# 1226       (5) Agriculture & related subjects     63.87   36.13     0.00
# 108                  (1) Medicine & dentistry     64.52   36.02     0.00
# 2796                       (B) Social studies     69.72   30.18     0.10
# 4992                            (I) Education     72.13   27.87     0.10
# 417           (2) Subjects allied to medicine     77.89   21.98     0.13

# %%
# Plot First Year Percentage of Male, Female, Other for 2017-2018
first_wales.plot(kind='bar', x='Area',
                    stacked=True,  
                    figsize=(14, 14))

plt.legend(loc="upper left", ncol=3)
plt.title("First Year Students in Wales, 2017-2018 by Gender")
plt.xlabel("Proportion")
plt.ylabel("Subject Area")
plt.show()

# %%
# Create new df with just first year students for Northen Ireland as in the df - there is no numbers for Others
ni = df1[(df1["Year"]=="First year")&(df1["Level"]=="All")
                     &(df1["Mode"]=="All")&(df1["Country"]=="Northern Ireland")]

# %%
# Create new df as in the df - there is no numbers for Others
niall = df1[(df1["Country"]=="Northern Ireland")]

niall.head(50)
# Out:
#                          Area         Year                    Level  \
# 2    (1) Medicine & dentistry          All                      All
# 7    (1) Medicine & dentistry          All                      All
# 12   (1) Medicine & dentistry          All                      All
# 17   (1) Medicine & dentistry          All         All postgraduate
# 22   (1) Medicine & dentistry          All         All postgraduate
# 27   (1) Medicine & dentistry          All         All postgraduate
# 32   (1) Medicine & dentistry          All        All undergraduate
# 37   (1) Medicine & dentistry          All        All undergraduate
# 42   (1) Medicine & dentistry          All        All undergraduate
# 47   (1) Medicine & dentistry          All             First degree
# 52   (1) Medicine & dentistry          All             First degree
# 57   (1) Medicine & dentistry          All             First degree
# 62   (1) Medicine & dentistry          All      Other undergraduate
# 67   (1) Medicine & dentistry          All      Other undergraduate
# 76   (1) Medicine & dentistry          All  Postgraduate (research)
# 81   (1) Medicine & dentistry          All  Postgraduate (research)
# 86   (1) Medicine & dentistry          All  Postgraduate (research)
# 91   (1) Medicine & dentistry          All    Postgraduate (taught)
# 96   (1) Medicine & dentistry          All    Postgraduate (taught)
# 101  (1) Medicine & dentistry          All    Postgraduate (taught)
# 106  (1) Medicine & dentistry   First year                      All
# 111  (1) Medicine & dentistry   First year                      All
# 116  (1) Medicine & dentistry   First year                      All
# 121  (1) Medicine & dentistry   First year         All postgraduate
# 126  (1) Medicine & dentistry   First year         All postgraduate
# 131  (1) Medicine & dentistry   First year         All postgraduate
# 136  (1) Medicine & dentistry   First year        All undergraduate
# 141  (1) Medicine & dentistry   First year        All undergraduate
# 146  (1) Medicine & dentistry   First year        All undergraduate
# 151  (1) Medicine & dentistry   First year             First degree
# 156  (1) Medicine & dentistry   First year             First degree
# 161  (1) Medicine & dentistry   First year             First degree
# 177  (1) Medicine & dentistry   First year  Postgraduate (research)
# 182  (1) Medicine & dentistry   First year  Postgraduate (research)
# 187  (1) Medicine & dentistry   First year  Postgraduate (research)
# 192  (1) Medicine & dentistry   First year    Postgraduate (taught)
# 197  (1) Medicine & dentistry   First year    Postgraduate (taught)
# 202  (1) Medicine & dentistry   First year    Postgraduate (taught)
# 207  (1) Medicine & dentistry  Other years                      All
# 212  (1) Medicine & dentistry  Other years                      All
# 217  (1) Medicine & dentistry  Other years                      All
# 222  (1) Medicine & dentistry  Other years         All postgraduate
# 227  (1) Medicine & dentistry  Other years         All postgraduate
# 232  (1) Medicine & dentistry  Other years         All postgraduate
# 237  (1) Medicine & dentistry  Other years        All undergraduate
# 242  (1) Medicine & dentistry  Other years        All undergraduate
# 247  (1) Medicine & dentistry  Other years        All undergraduate
# 252  (1) Medicine & dentistry  Other years             First degree
# 257  (1) Medicine & dentistry  Other years             First degree
# 262  (1) Medicine & dentistry  Other years             First degree
#
#           Mode           Country  Female  Male  Other  Total  Female %  \
# 2          All  Northern Ireland    1350   805      0   2160     62.50
# 7    Full-time  Northern Ireland    1195   685      0   1880     63.56
# 12   Part-time  Northern Ireland     155   120      0    275     56.36
# 17         All  Northern Ireland     350   215      0    565     61.95
# 22   Full-time  Northern Ireland     205   110      0    310     66.13
# 27   Part-time  Northern Ireland     145   110      0    255     56.86
# 32         All  Northern Ireland    1005   590      0   1595     63.01
# 37   Full-time  Northern Ireland     995   575      0   1570     63.38
# 42   Part-time  Northern Ireland      10    15      0     25     40.00
# 47         All  Northern Ireland    1005   590      0   1595     63.01
# 52   Full-time  Northern Ireland     995   575      0   1570     63.38
# 57   Part-time  Northern Ireland      10    15      0     25     40.00
# 62         All  Northern Ireland       0     0      0      0       NaN
# 67   Full-time  Northern Ireland       0     0      0      0       NaN
# 76         All  Northern Ireland     155    90      0    245     63.27
# 81   Full-time  Northern Ireland     135    75      0    210     64.29
# 86   Part-time  Northern Ireland      15    15      0     35     42.86
# 91         All  Northern Ireland     195   125      0    320     60.94
# 96   Full-time  Northern Ireland      65    35      0    100     65.00
# 101  Part-time  Northern Ireland     130    90      0    220     59.09
# 106        All  Northern Ireland     405   220      0    630     64.29
# 111  Full-time  Northern Ireland     325   160      0    485     67.01
# 116  Part-time  Northern Ireland      80    65      0    145     55.17
# 121        All  Northern Ireland     185   115      0    300     61.67
# 126  Full-time  Northern Ireland     100    50      0    155     64.52
# 131  Part-time  Northern Ireland      80    65      0    145     55.17
# 136        All  Northern Ireland     225   105      0    330     68.18
# 141  Full-time  Northern Ireland     225   105      0    330     68.18
# 146  Part-time  Northern Ireland       0     0      0      0       NaN
# 151        All  Northern Ireland     225   105      0    330     68.18
# 156  Full-time  Northern Ireland     225   105      0    330     68.18
# 161  Part-time  Northern Ireland       0     0      0      0       NaN
# 177        All  Northern Ireland      45    25      0     75     60.00
# 182  Full-time  Northern Ireland      45    25      0     70     64.29
# 187  Part-time  Northern Ireland       0     0      0      5      0.00
# 192        All  Northern Ireland     135    90      0    225     60.00
# 197  Full-time  Northern Ireland      55    25      0     80     68.75
# 202  Part-time  Northern Ireland      80    60      0    140     57.14
# 207        All  Northern Ireland     945   585      0   1530     61.76
# 212  Full-time  Northern Ireland     875   525      0   1400     62.50
# 217  Part-time  Northern Ireland      75    60      0    130     57.69
# 222        All  Northern Ireland     165   100      0    265     62.26
# 227  Full-time  Northern Ireland     100    55      0    160     62.50
# 232  Part-time  Northern Ireland      65    45      0    110     59.09
# 237        All  Northern Ireland     780   485      0   1265     61.66
# 242  Full-time  Northern Ireland     770   470      0   1240     62.10
# 247  Part-time  Northern Ireland      10    15      0     25     40.00
# 252        All  Northern Ireland     780   485      0   1265     61.66
# 257  Full-time  Northern Ireland     770   470      0   1240     62.10
# 262  Part-time  Northern Ireland      10    15      0     25     40.00
#
#      Male %  Other %
# 2     37.27      0.0
# 7     36.44      0.0
# 12    43.64      0.0
# 17    38.05      0.0
# 22    35.48      0.0
# 27    43.14      0.0
# 32    36.99      0.0
# 37    36.62      0.0
# 42    60.00      0.0
# 47    36.99      0.0
# 52    36.62      0.0
# 57    60.00      0.0
# 62      NaN      NaN
# 67      NaN      NaN
# 76    36.73      0.0
# 81    35.71      0.0
# 86    42.86      0.0
# 91    39.06      0.0
# 96    35.00      0.0
# 101   40.91      0.0
# 106   34.92      0.0
# 111   32.99      0.0
# 116   44.83      0.0
# 121   38.33      0.0
# 126   32.26      0.0
# 131   44.83      0.0
# 136   31.82      0.0
# 141   31.82      0.0
# 146     NaN      NaN
# 151   31.82      0.0
# 156   31.82      0.0
# 161     NaN      NaN
# 177   33.33      0.0
# 182   35.71      0.0
# 187    0.00      0.0
# 192   40.00      0.0
# 197   31.25      0.0
# 202   42.86      0.0
# 207   38.24      0.0
# 212   37.50      0.0
# 217   46.15      0.0
# 222   37.74      0.0
# 227   34.38      0.0
# 232   40.91      0.0
# 237   38.34      0.0
# 242   37.90      0.0
# 247   60.00      0.0
# 252   38.34      0.0
# 257   37.90      0.0
# 262   60.00      0.0

# %%
# Filter df again
subset = ni.iloc[:, [0,9,10,11]]

# %%
# Reorder rows
first_ni = subset.sort_values(by='Female %')

# %%
# Check new df
first_ni
# Out:
#                                          Area  Female %  Male %  Other %
# 2479             (9) Engineering & technology     23.19   76.81      0.0
# 2165                     (8) Computer science     25.17   74.83      0.0
# 1852                (7) Mathematical sciences     42.86   57.14      0.0
# 1537                    (6) Physical sciences     44.64   55.36      0.0
# 4360   (G) Historical & philosophical studies     52.22   46.67      0.0
# 3424    (D) Business & administrative studies     52.66   47.18      0.0
# 5298                             (J) Combined     55.56   44.44      0.0
# 6222            Total - Science subject areas     56.93   43.07      0.0
# 3736  (E) Mass communications & documentation     58.97   41.03      0.0
# 5592                                    Total     60.10   39.90      0.0
# 5907        Total - Non-science subject areas     62.54   37.46      0.0
# 730                   (3) Biological sciences     63.60   36.40      0.0
# 4675               (H) Creative arts & design     64.00   35.33      0.0
# 106                  (1) Medicine & dentistry     64.29   34.92      0.0
# 1224       (5) Agriculture & related subjects     64.52   35.48      0.0
# 3109                                  (C) Law     65.28   34.72      0.0
# 4990                            (I) Education     67.15   32.96      0.0
# 2794                       (B) Social studies     67.16   33.09      0.0
# 4045                            (F) Languages     72.13   27.87      0.0
# 415           (2) Subjects allied to medicine     84.01   15.99      0.0

# %%
# Plot First Year Percentage of Male, Female, Other for 2017-2018
first_ni.plot(kind='bar', x='Area',
                    stacked=True,  
                    figsize=(14, 14))

plt.legend(loc="upper left", ncol=3)
plt.title("First Year Students in Northern Ireland, 2017-2018 by Gender")
plt.xlabel("Proportion")
plt.ylabel("Subject Area")
plt.show()
